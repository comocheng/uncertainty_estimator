# %%
import cantera as ct
import backmixing_simulation
import logging
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
logging.basicConfig()
logging.getLogger().setLevel(logging.DEBUG)

# %%
mech_yaml = '/home/moon/uncertainty_estimator/cpox_pt/cpox_pt_20260130/cantera/chem_annotated_mod.yaml'

# %%
gas_out, surf_out, gas_rates, surf_rates = backmixing_simulation.run_simulation(mech_yaml, n_iter=1, backmixing=0)
# Out:
# DEBUG:root:Loaded mechanism file: /home/moon/uncertainty_estimator/cpox_pt/cpox_pt_20260130/cantera/chem_annotated_mod.yaml
# Starting iteration 1/1 of the backmixing simulation with backmixing fraction 0

# %%
gas = ct.Solution(mech_yaml)
surf = ct.Interface(mech_yaml, "surface1", [gas])

# %%
backmixing_simulation.plot_gas_results(gas_out, mech_yaml)
# Out:
# DEBUG:matplotlib.font_manager:findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0.
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home/moon/miniforge3/envs/ct-env/lib/python3.13/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-BoldItalic.ttf', name='DejaVu Serif', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# DEBUG:matplotlib.font_manager:findfont: score(FontEntry(fname='/home/moon/miniforge3/envs/ct-env/lib/python3.13/site-packages/matplotlib/mpl-data/fonts/ttf/cmmi10.ttf', name='cmmi10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# ...

# %%
gas_out_b, surf_out_b, gas_rates_b, surf_rates_b = backmixing_simulation.run_simulation(mech_yaml, n_iter=100, backmixing=0.2)
# Out:
# DEBUG:root:Loaded mechanism file: /home/moon/uncertainty_estimator/cpox_pt/cpox_pt_20260130/cantera/chem_annotated_mod.yaml
# Starting iteration 1/100 of the backmixing simulation with backmixing fraction 0.2
# Starting iteration 2/100 of the backmixing simulation with backmixing fraction 0.2
# Starting iteration 3/100 of the backmixing simulation with backmixing fraction 0.2
# Starting iteration 4/100 of the backmixing simulation with backmixing fraction 0.2
# Starting iteration 5/100 of the backmixing simulation with backmixing fraction 0.2
# Starting iteration 6/100 of the backmixing simulation with backmixing fraction 0.2
# Starting iteration 7/100 of the backmixing simulation with backmixing fraction 0.2
# Starting iteration 8/100 of the backmixing simulation with backmixing fraction 0.2
# Starting iteration 9/100 of the backmixing simulation with backmixing fraction 0.2
# Starting iteration 10/100 of the backmixing simulation with backmixing fraction 0.2
# ...

# %%
gas_b = ct.Solution(mech_yaml)
surf_b = ct.Interface(mech_yaml, "surface1", [gas_b])

# %%
backmixing_simulation.plot_gas_results(gas_out_b, mech_yaml)
