# %%
# If my MAE is 6.9, do I know the standard deviation of the normal distribution?

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
0.1 * np.sqrt(2.0 / np.pi)
# Out:
# 0.07978845608028655

# %%
sigma = 6.5 / (np.sqrt(2.0) * 0.476936276204469873381)

# %%
sigma = 3.0 / np.sqrt(2.0 / np.pi)

# %%
sigma
# Out:
# 8.14654189255075

# %%
uniform = 0.25* ()

# %%
np.random.seed(400)
Xs = np.random.normal(0, sigma, 100000)

# %%
MAE = np.average(np.abs(Xs))

# %%
MAE
# Out:
# 6.483469785176342

# %%
plt.hist(Xs, 64)
# Out:
# (array([1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00,
#         1.000e+00, 1.000e+00, 2.000e+00, 8.000e+00, 1.700e+01, 2.200e+01,
#         3.200e+01, 6.200e+01, 7.700e+01, 1.250e+02, 1.920e+02, 2.940e+02,
#         4.070e+02, 5.640e+02, 7.700e+02, 1.055e+03, 1.400e+03, 1.860e+03,
#         2.169e+03, 2.762e+03, 3.254e+03, 3.842e+03, 4.367e+03, 4.750e+03,
#         5.270e+03, 5.813e+03, 5.836e+03, 6.005e+03, 6.024e+03, 5.863e+03,
#         5.626e+03, 5.136e+03, 4.643e+03, 4.136e+03, 3.721e+03, 3.169e+03,
#         2.569e+03, 2.036e+03, 1.629e+03, 1.286e+03, 9.870e+02, 6.870e+02,
#         4.720e+02, 3.550e+02, 2.430e+02, 1.640e+02, 1.070e+02, 7.400e+01,
#         4.900e+01, 2.700e+01, 1.400e+01, 1.000e+01, 8.000e+00, 2.000e+00,
#         2.000e+00, 0.000e+00, 0.000e+00, 2.000e+00]),
#  array([-35.28811574, -34.24542151, -33.20272728, -32.16003305,
#         -31.11733881, -30.07464458, -29.03195035, -27.98925612,
# ...
