# %% [markdown]
# # Notebook to show off as many use cases / edge cases of uncertainty as we can think of (will form basis of pytest module later)

# %%
import os
import sys
import pickle
import copy
import numpy as np
import rmgpy.rmg.input  # note this method is currently broken for multiple reactors in an input file
import rmgpy.rmg.main
import rmgpy.chemkin
import rmgpy.tools.uncertainty
import rmgpy.kinetics.uncertainties

import rmgpy.tools.canteramodel
import random

import rmgpy.kinetics
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def get_i_thing(thing, thing_list):
    for i in range(len(thing_list)):
        if thing.is_isomorphic(thing_list[i]):
            return i
    raise AssertionError(f'Could not find {thing} in list of {len(thing_list)} things')

# %%
def pad_to_length(input_str, length):
    input_str = str(input_str)
    if len(input_str) > length:
        print('Pad length for this string must be at least', len(input_str))
        raise ValueError
    return input_str + ' ' * (length - len(input_str))

# %%
CH4 = rmgpy.species.Species(smiles='C')
CH3 = rmgpy.species.Species(smiles='[CH3]')
C2H4 = rmgpy.species.Species().from_smiles('C=C')

# %% [markdown]
# ## Load Mech_02_surf_ethane_lib

# %%
# Must use annotated chemkin file
chemkin_file = './mech_06_ethane_beef/chemkin/chem_annotated-gas.inp'
mech_dir = os.path.dirname(chemkin_file)
surface = os.path.join(mech_dir, 'chem_annotated-surface.inp')
dict_file = os.path.join(mech_dir, 'species_dictionary.txt')
input_file = os.path.join(os.path.dirname(mech_dir), 'input.py')

# Run Gao estimation of input parameters (takes a long time to load database)
uncertainty = rmgpy.tools.uncertainty.Uncertainty(
    output_directory=os.path.join(mech_dir, 'uncertainty'),
    thermo_corr_dir='/home/moon/rmg/RMG-database/input/thermo/uncertainty'
)
uncertainty.load_model(chemkin_file, dict_file, surface_path=surface)

# %%
# load the database either copying libraries manually or using the input file
thermo_libs = [
    'surfaceThermoPt111',
    'primaryThermoLibrary'
]
kinetics_libs = [
    'O2_dissociative_adsorption',
    'Surface/CPOX_Pt/Deutschmann2006_adjusted',
    'BurkeH2O2inArHe',
]

kinetics_families = [
    'default',
    'Surface_Adsorption_Single',
    'Surface_Adsorption_vdW',
    'Surface_Adsorption_Dissociative',
    'Surface_Dissociation',
    'Surface_Abstraction',
    'Surface_Dissociation_Double_vdW',
    'Surface_Dissociation_vdW',
    'Surface_Abstraction_vdW',
    'Surface_Dissociation_Beta',
    'Surface_Adsorption_Bidentate',
    'Surface_Bidentate_Dissociation',
    'Surface_Monodentate_to_Bidentate',
    'Surface_Dissociation_to_Bidentate', 
    'Surface_vdW_to_Bidentate',
    'Surface_Adsorption_Dissociative_Double',
    'Surface_Abstraction_Beta',
    # 'Surface_Abstraction_Beta_double_vdW',
    'Surface_Dissociation_Double',
    'Surface_Dissociation_Beta_vdW',
    'Surface_Abstraction_Beta_vdW',
    'Surface_Abstraction_Single_vdW',
]


uncertainty.load_database(  # this call does the averaging up of kinetics families
    thermo_libraries=thermo_libs,
    kinetics_families=kinetics_families,
    # kinetics_families=['R_Addition_MultipleBond'],
    reaction_libraries=kinetics_libs,
    # kinetics_depositories=['training'],
)
# Out:
# WARNING:root:Cphigh is above the theoretical CpInf value for ThermoData object
# ThermoData(Tdata=([300,400,500,600,800,1000,1500],'K'), Cpdata=([60.2599,68.0494,74.7775,80.9311,90.8846,97.4337,105.393],'J/(mol*K)'), H298=(-477.191,'kJ/mol'), S298=(269.551,'J/(mol*K)'), Cp0=(33.2579,'J/(mol*K)'), CpInf=(103.931,'J/(mol*K)'), comment="""Thermo group additivity estimation: group(O2s-(Cds-Cd)(Cds-Cd)) + group(O2s-(Cds-O2d)H) + group(Cds-OdOsOs) + group(Li-OCOdO) + radical(OC=OOJ)""").
# The thermo for this species is probably wrong! Setting CpInf = Cphigh for Entropy calculationat T = 2000.0 K...
# WARNING:root:Cphigh is above the theoretical CpInf value for ThermoData object
# ThermoData(Tdata=([300,400,500,600,800,1000,1500],'K'), Cpdata=([60.2599,68.0494,74.7775,80.9311,90.8846,97.4337,105.393],'J/(mol*K)'), H298=(-477.191,'kJ/mol'), S298=(269.551,'J/(mol*K)'), Cp0=(33.2579,'J/(mol*K)'), CpInf=(103.931,'J/(mol*K)'), comment="""Thermo group additivity estimation: group(O2s-(Cds-Cd)(Cds-Cd)) + group(O2s-(Cds-O2d)H) + group(Cds-OdOsOs) + group(Li-OCOdO) + radical(OC=OOJ)""").
# The thermo for this species is probably wrong! Setting CpInf = Cphigh for Entropy calculationat T = 1666.6666666666665 K...
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Pt'. Using 'Pt111'.
# WARNING:root:Found multiple binding energies for 'Pt'. Using 'Pt111'.
# WARNING:root:Found multiple binding energies for 'Pt'. Using 'Pt111'.
# WARNING:root:Found multiple binding energies for 'Pt'. Using 'Pt111'.
# WARNING:root:Found multiple binding energies for 'Pt'. Using 'Pt111'.
# WARNING:root:Found multiple binding energies for 'Pt'. Using 'Pt111'.
# WARNING:root:Found multiple binding energies for 'Pt'. Using 'Pt111'.
# WARNING:root:Found multiple binding energies for 'Pt'. Using 'Pt111'.
# WARNING:root:Found multiple binding energies for 'Pt'. Using 'Pt111'.
# WARNING:root:Found multiple binding energies for 'Pt'. Using 'Pt111'.
# WARNING:root:Found multiple binding energies for 'Pt'. Using 'Pt111'.
# WARNING:root:Found multiple binding energies for 'Pt'. Using 'Pt111'.
# WARNING:root:Found multiple binding energies for 'Pt'. Using 'Pt111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Ni'. Using 'Ni111'.
# WARNING:root:Found multiple binding energies for 'Ni'. Using 'Ni111'.
# WARNING:root:Found multiple binding energies for 'Ni'. Using 'Ni111'.
# WARNING:root:Found multiple binding energies for 'Ni'. Using 'Ni111'.
# WARNING:root:Found multiple binding energies for 'Ni'. Using 'Ni111'.
# WARNING:root:Found multiple binding energies for 'Ni'. Using 'Ni111'.
# WARNING:root:Found multiple binding energies for 'Ni'. Using 'Ni111'.
# WARNING:root:Found multiple binding energies for 'Ni'. Using 'Ni111'.
# WARNING:root:Found multiple binding energies for 'Ni'. Using 'Ni111'.
# WARNING:root:Found multiple binding energies for 'Ni'. Using 'Ni111'.
# WARNING:root:Found multiple binding energies for 'Ni'. Using 'Ni111'.
# WARNING:root:Found multiple binding energies for 'Ni'. Using 'Ni111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Pt'. Using 'Pt111'.
# WARNING:root:Found multiple binding energies for 'Pt'. Using 'Pt111'.
# WARNING:root:Found multiple binding energies for 'Pt'. Using 'Pt111'.
# WARNING:root:Found multiple binding energies for 'Pt'. Using 'Pt111'.
# WARNING:root:Found multiple binding energies for 'Pt'. Using 'Pt111'.
# WARNING:root:Found multiple binding energies for 'Pt'. Using 'Pt111'.
# WARNING:root:Found multiple binding energies for 'Pt'. Using 'Pt111'.
# WARNING:root:Found multiple binding energies for 'Pt'. Using 'Pt111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Ni'. Using 'Ni111'.
# WARNING:root:Found multiple binding energies for 'Ni'. Using 'Ni111'.
# WARNING:root:Found multiple binding energies for 'Ni'. Using 'Ni111'.
# WARNING:root:Found multiple binding energies for 'Ni'. Using 'Ni111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Pt'. Using 'Pt111'.
# WARNING:root:Found multiple binding energies for 'Pt'. Using 'Pt111'.
# WARNING:root:Found multiple binding energies for 'Pt'. Using 'Pt111'.
# WARNING:root:Found multiple binding energies for 'Pt'. Using 'Pt111'.
# WARNING:root:Found multiple binding energies for 'Pt'. Using 'Pt111'.
# WARNING:root:Found multiple binding energies for 'Pt'. Using 'Pt111'.
# WARNING:root:Found multiple binding energies for 'Pt'. Using 'Pt111'.
# WARNING:root:Found multiple binding energies for 'Pt'. Using 'Pt111'.
# WARNING:root:Found multiple binding energies for 'Pt'. Using 'Pt111'.
# WARNING:root:Found multiple binding energies for 'Pt'. Using 'Pt111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.
# WARNING:root:Found multiple binding energies for 'Cu'. Using 'Cu111'.

# %%
# # make sure CH3 hasn't been added to primaryThermoLibrary
# thermo_lib_item_list = [uncertainty.database.thermo.libraries['primaryThermoLibrary'].entries[key].item \
#                             for key in uncertainty.database.thermo.libraries['primaryThermoLibrary'].entries.keys()]
# assert not any([CH3.is_isomorphic(item) for item in thermo_lib_item_list]), "You need a new test if CH3 gets into the primaryThermoLibrary"

# %% [markdown]
# ### Uncorrelated test cases

# %%
# Get the different kinetic and thermo sources
uncertainty.extract_sources_from_model()
uncertainty.assign_parameter_uncertainties()
uncertainty.compile_all_sources()

# %%
uncertainty.all_thermo_sources
# Out:
# {'Library': [0, 1, 2, 3, 4, 6, 7, 8, 13, 18],
#  'QM': [],
#  'GAV': {'group': [<Entry index=2335 label="O2s-OsCs">,
#    <Entry index=923 label="Cs-(Cds-O2d)HHH">,
#    <Entry index=1952 label="Cs-CsOsHH">,
#    <Entry index=119 label="Cdd-OdOd">,
#    <Entry index=318 label="Cds-CdsOsH">,
#    <Entry index=253 label="Cds-OdCsOs">,
#    <Entry index=311 label="Cds-(Cdd-O2d)HH">,
#    <Entry index=309 label="Cds-CdsHH">,
#    <Entry index=2317 label="O2s-OsH">,
#    <Entry index=934 label="Cs-OsHHH">,
#    <Entry index=242 label="Cds-OdCsH">,
#    <Entry index=2324 label="O2s-(Cds-O2d)H">,
#    <Entry index=2325 label="O2s-(Cds-Cd)H">,
#    <Entry index=2327 label="O2s-CsH">,
#    <Entry index=953 label="Cs-CsCsHH">,
#    <Entry index=921 label="Cs-CsHHH">,
#    <Entry index=233 label="Cds-OdOsH">,
#    <Entry index=232 label="Cds-OdHH">,
#    <Entry index=935 label="Cs-OsOsHH">],
#   'radical': [<Entry index=1339 label="OCJO">,
#    <Entry index=1872 label="ROOJ">,
#    <Entry index=1478 label="(O)CJOH">,
#    <Entry index=1978 label="CCJ2_triplet">,
#    <Entry index=796 label="CH3">,
#    <Entry index=1463 label="CsCJ=O">,
#    <Entry index=840 label="CCJ">,
#    <Entry index=1441 label="HCdsJO">]},
#  'ADS': {'adsorptionPt111': [<Entry index=39 label="C-*R2C-*R2">,
#    <Entry index=89 label="(CR2CR)*">,
#    <Entry index=65 label="C=*RO-*">,
#    <Entry index=88 label="C-*R2O-*">,
#    <Entry index=53 label="C-*R2OR">,
#    <Entry index=93 label="C-*R2C-*R">,
#    <Entry index=42 label="(CR4)*">,
#    <Entry index=73 label="C*O*">]}}

# %%
ThermoEngine = rmgpy.tools.uncertainty.ThermoParameterUncertainty()
print('dG_GAV  \t', ThermoEngine.dG_GAV)
print('dG_group\t', ThermoEngine.dG_group)
print('dG_library\t', ThermoEngine.dG_library)
print('dG_surf_lib\t', ThermoEngine.dG_surf_lib)
print('dG_ads_grp\t', ThermoEngine.dG_ADS_group)
# Out:
# dG_GAV  	 1.5
# dG_group	 0.3162
# dG_library	 1.5
# dG_surf_lib	 6.918
# dG_ads_grp	 6.918

# %% [markdown]
# # See at a glance what kind of species estimates are in the mech

# %%
print('Index', '\tSpecies', '\tSources', '\tUncertainty kcal/mol')
print('----------------------------------------------------------')
for i in range(len(uncertainty.species_list)):
    print(i, '\t',
          pad_to_length(uncertainty.species_list[i], 18),
          pad_to_length(set(uncertainty.species_sources_dict[uncertainty.species_list[i]].keys()), 30),
          '\t', f'{uncertainty.thermo_input_uncertainties[i]:.4f}'
         )
# Out:
# Index 	Species 	Sources 	Uncertainty kcal/mol
# ----------------------------------------------------------
# 0 	 Ar                 {'Library'}                    	 1.5000
# 1 	 Ne                 {'Library'}                    	 1.5000
# 2 	 N2                 {'Library'}                    	 1.5000
# 3 	 CH4(2)             {'Library'}                    	 1.5000
# 4 	 O2(3)              {'Library'}                    	 1.5000
# 5 	 CO2(4)             {'GAV'}                        	 1.5330
# 6 	 H2O(5)             {'Library'}                    	 1.5000
# 7 	 H2(6)              {'Library'}                    	 1.5000
# 8 	 CO(7)              {'Library'}                    	 1.5000
# 9 	 C2H6(8)            {'GAV'}                        	 1.6279
# 10 	 CH2O(9)            {'GAV'}                        	 1.5330
# 11 	 CH3(10)            {'GAV', 'Library'}             	 2.1448
# 12 	 C3H8(11)           {'GAV'}                        	 1.6583
# 13 	 H(12)              {'Library'}                    	 1.5000
# 14 	 C2H5(13)           {'GAV'}                        	 1.6583
# 15 	 CH3OH(14)          {'GAV'}                        	 1.5652
# 16 	 HCO(15)            {'GAV'}                        	 1.5652
# 17 	 CH3CHO(16)         {'GAV'}                        	 1.5652
# 18 	 OH(17)             {'Library'}                    	 1.5000
# 19 	 C2H4(18)           {'GAV'}                        	 1.6279
# 20 	 CH3CH(19)          {'GAV'}                        	 1.6583
# 21 	 CH3OO(20)          {'GAV'}                        	 1.6279
# 22 	 O=CO(78)           {'GAV'}                        	 1.5652
# 23 	 CC(=O)O(99)        {'GAV'}                        	 1.5969
# 24 	 CCO(107)           {'GAV'}                        	 1.5969
# 25 	 X(1)               {'Library_surface'}            	 6.9180
# 26 	 HX(21)             {'Library_surface'}            	 6.9180
# 27 	 CO2X(22)           {'Library_surface'}            	 6.9180
# 28 	 COX(23)            {'Library_surface'}            	 6.9180
# 29 	 CH4X(24)           {'Library_surface'}            	 6.9180
# 30 	 OX(25)             {'Library_surface'}            	 6.9180
# 31 	 CH2X(26)           {'Library_surface'}            	 6.9180
# 32 	 CH3X(27)           {'Library_surface'}            	 6.9180
# 33 	 CHX(28)            {'Library_surface'}            	 6.9180
# 34 	 CX(29)             {'Library_surface'}            	 6.9180
# 35 	 H2X(30)            {'Library_surface'}            	 6.9180
# 36 	 OHX(31)            {'Library_surface'}            	 6.9180
# 37 	 H2OX(32)           {'Library_surface'}            	 6.9180
# 38 	 CHOX(33)           {'Library_surface'}            	 6.9180
# 39 	 C[CH2][Pt](54)     {'Library_surface'}            	 6.9180
# 40 	 CC.[Pt](55)        {'Library_surface'}            	 6.9180
# 41 	 CH2OX2(56)         {'Library_surface'}            	 6.9180
# 42 	 C=O.[Pt](57)       {'Library_surface'}            	 6.9180
# 43 	 C[O][Pt](58)       {'Library_surface'}            	 6.9180
# 44 	 O[CH2][Pt](59)     {'Library_surface'}            	 6.9180
# 45 	 CO.[Pt](60)        {'Library_surface'}            	 6.9180
# 46 	 C[C](=O)[Pt](63)   {'Library_surface'}            	 6.9180
# 47 	 C[CH]=[Pt](64)     {'Library_surface'}            	 6.9180
# 48 	 C=[CH][Pt](67)     {'Library_surface'}            	 6.9180
# 49 	 CHOX2(70)          {'Library_surface'}            	 6.9180
# 50 	 O[C]#[Pt](88)      {'Library_surface'}            	 6.9180
# 51 	 C2H2OX2(90)        {'GAV', 'ADS'}                 	 9.9029
# 52 	 C=C=O.[Pt](91)     {'Library_surface'}            	 6.9180
# 53 	 O=[C](O)[Pt](96)   {'Library_surface'}            	 6.9180
# 54 	 O[CH]=[Pt](119)    {'Library_surface'}            	 6.9180
# 55 	 C[C]#[Pt](122)     {'Library_surface'}            	 6.9180
# 56 	 C2H3X2(123)        {'Library_surface'}            	 6.9180
# 57 	 C2H2X2(124)        {'Library_surface'}            	 6.9180
# 58 	 O=CO.[Pt](132)     {'Library_surface'}            	 6.9180
# 59 	 CCO.[Pt](136)      {'Library_surface'}            	 6.9180
# 60 	 C[CH](O)[Pt](138)  {'Library_surface'}            	 6.9180
# 61 	 C2H3OX2(139)       {'GAV', 'ADS'}                 	 9.9130
# 62 	 C[C](O)=[Pt](140)  {'Library_surface'}            	 6.9180
# 63 	 CH2O2X2(141)       {'GAV', 'ADS'}                 	 9.9079
# 64 	 C2H4OX2(145)       {'GAV', 'ADS'}                 	 9.9130
# 65 	 C=CO.[Pt](146)     {'GAV', 'ADS'}                 	 9.9130
# 66 	 O[CH](O)[Pt](152)  {'GAV', 'ADS'}                 	 9.9281
# 67 	 CHO2X2(157)        {'GAV', 'ADS'}                 	 9.9130
# 68 	 C2H3OX2(160)       {'Library_surface'}            	 6.9180
# 69 	 C=[C](O)[Pt](161)  {'Library_surface'}            	 6.9180
# 70 	 C2H4O2X2(169)      {'GAV', 'ADS'}                 	 9.9130
# 71 	 CC(=O)O.[Pt](170)  {'GAV', 'ADS'}                 	 9.9130
# 72 	 OC[O][Pt](182)     {'Library_surface'}            	 6.9180
# 73 	 C2H2OX2(254)       {'GAV', 'ADS'}                 	 9.9029

# %% [markdown]
# # Export the covariance matrix

# %%
# Get the different kinetic and thermo sources
uncertainty.extract_sources_from_model()
uncertainty.assign_parameter_uncertainties(correlated=True)
uncertainty.compile_all_sources()

# %%
cov_G = uncertainty.get_thermo_covariance_matrix()
cov_k = uncertainty.get_kinetic_covariance_matrix()
cov_total = uncertainty.get_overall_covariance_matrix()
# Out:
# WARNING:root:Resonance structure generation failed for <Molecule "[O-][N+](=O)[O].[O-][N+]=O">

# %%
divider = np.argmax([x.contains_surface_site() for x in uncertainty.species_list]) - 0.5

fig, axs = plt.subplots(1, 2)
fig.set_figwidth(10)
mat1 = axs[0].matshow(cov_G)
cb1 = plt.colorbar(mat1, ax=axs[0])
cb1.ax.set_title(r'$(kcal/mol)^2$')

axs[0].axvline(x=divider, color='w', linewidth=0.75)
axs[0].axhline(y=divider, color='w', linewidth=0.75)
axs[0].set_xlabel('     Gas Species           Surface Species')
axs[0].set_ylabel('Surface Species              Gas Species')



mat2 = axs[1].matshow(cov_G)
cb2 = plt.colorbar(mat2, ax=axs[1])
mat2.set_clim([0, 0.5])
cb2.ax.set_title(r'$(kcal/mol)^2$')
axs[1].axvline(x=divider, color='w', linewidth=0.75)
axs[1].axhline(y=divider, color='w', linewidth=0.75)
axs[1].set_xlabel('     Gas Species           Surface Species')
axs[1].set_ylabel('Surface Species              Gas Species')
# Out:
# Text(0, 0.5, 'Surface Species              Gas Species')

# %% [markdown]
# # kinetics cov

# %%
divider = np.argmax([x.is_surface_reaction() for x in uncertainty.reaction_list]) - 0.5

fig, axs = plt.subplots(1, 2)
fig.set_figwidth(10)
mat1 = axs[0].matshow(cov_k)
cb1 = plt.colorbar(mat1, ax=axs[0])
cb1.ax.set_title(r'$(kcal/mol)^2$')
axs[0].axvline(x=divider, color='w', linewidth=0.75)
axs[0].axhline(y=divider, color='w', linewidth=0.75)
axs[0].set_xlabel('     Gas Reactions           Surface Reactions')
axs[0].set_ylabel('Surface Reactions              Gas Reactions')



mat2 = axs[1].matshow(cov_k)
cb2 = plt.colorbar(mat2, ax=axs[1])
mat2.set_clim([0, 0.5])
cb2.ax.set_title(r'$(kcal/mol)^2$')
axs[1].axvline(x=divider, color='w', linewidth=0.75)
axs[1].axhline(y=divider, color='w', linewidth=0.75)
axs[1].set_xlabel('     Gas Reactions           Surface Reactions')
axs[1].set_ylabel('Surface Reactions              Gas Reactions')
# Out:
# Text(0, 0.5, 'Surface Reactions              Gas Reactions')

# %% [markdown]
# # Overall cov

# %%
divider = len(uncertainty.species_list) - 0.5

fig, axs = plt.subplots(1, 2)
fig.set_figwidth(10)
mat1 = axs[0].matshow(cov_total)
cb1 = plt.colorbar(mat1, ax=axs[0])
cb1.ax.set_title(r'$(kcal/mol)^2$')
axs[0].axvline(x=divider, color='w', linewidth=0.75)
axs[0].axhline(y=divider, color='w', linewidth=0.75)
axs[0].set_xlabel('     Gas Reactions           Surface Reactions')
axs[0].set_ylabel('Surface Reactions              Gas Reactions')



mat2 = axs[1].matshow(cov_total)
cb2 = plt.colorbar(mat2, ax=axs[1])
mat2.set_clim([0, 0.5])
cb2.ax.set_title(r'$(kcal/mol)^2$')
axs[1].axvline(x=divider, color='w', linewidth=0.75)
axs[1].axhline(y=divider, color='w', linewidth=0.75)
axs[1].set_xlabel('     Gas Reactions           Surface Reactions')
axs[1].set_ylabel('Surface Reactions              Gas Reactions')
# Out:
# Text(0, 0.5, 'Surface Reactions              Gas Reactions')

# %%
np.diagonal(cov_G)
# Out:
# array([ 2.25      ,  2.25      ,  2.25      ,  2.25      ,  2.25      ,
#         2.34998244,  2.25      ,  2.25      ,  2.25      ,  2.64992976,
#         2.34998244,  4.59998244,  2.7499122 ,  2.25      ,  2.7499122 ,
#         2.44996488,  2.44996488,  2.44996488,  2.25      ,  2.64992976,
#         2.7499122 ,  2.64992976,  2.44996488,  2.54994732,  2.54994732,
#        47.858724  , 49.30188821, 56.69568376, 53.01499584, 51.1602208 ,
#        59.08980191, 53.51797804, 54.33790292, 57.91457342, 71.25389946,
#        49.13581048, 55.84866794, 55.49727177, 56.72721892, 58.49529947,
#        55.75817187, 59.41570827, 70.45174029, 60.56723048, 59.65576058,
#        65.97184329, 62.28695798, 55.93551794, 57.74695792, 54.81168967,
#        58.77653387, 65.26839493, 64.67599247, 57.67094527, 60.021282  ,
#        59.57187229, 60.18566284, 70.24657193, 57.84711116, 50.24131099,
#        69.4859506 , 57.36163699, 65.71807506, 61.86567315, 61.01561935,
#        61.79351002, 66.93433899, 57.36163699, 64.71532393, 63.75930288,
#        61.96565559, 57.51761582, 67.99080082, 61.32668008])
